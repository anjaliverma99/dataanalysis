# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
import pandas as pd
df=pd.read_csv('auto.csv')
df.to_csv('new_auto.csv',index=False,header=["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"])

# %%
df.head(5)
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front  94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front  99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front  99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front  99.8  ...
#
#    130  mpfi  3.47  2.68   9.0  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
import numpy as np
df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...  \
# 0  3  NaN  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...
# 1  1  NaN  alfa-romero  gas  std   two    hatchback  rwd  front  94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front  99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front  99.4  ...
# 4  2  NaN         audi  gas  std   two        sedan  fwd  front  99.8  ...
#
#    130  mpfi  3.47  2.68   9.0  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#        3      ?  alfa-romero    gas    std    two  convertible    rwd  front  \
# 0  False  False        False  False  False  False        False  False  False
# 1  False  False        False  False  False  False        False  False  False
# 2  False  False        False  False  False  False        False  False  False
# 3  False  False        False  False  False  False        False  False  False
# 4  False  False        False  False  False  False        False  False  False
#
#     88.6  ...    130   mpfi   3.47   2.68    9.0    111   5000     21     27  \
# 0  False  ...  False  False  False  False  False  False  False  False  False
# 1  False  ...  False  False  False  False  False  False  False  False  False
# 2  False  ...  False  False  False  False  False  False  False  False  False
# 3  False  ...  False  False  False  False  False  False  False  False  False
# 4  False  ...  False  False  False  False  False  False  False  False  False
#
#    13495
# 0  False
# 1  False
# ...

# %%
import pandas as pd
df=pd.read_csv('auto.csv')
df.to_csv('new_auto.csv',index=False,header=["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"])
missing_data = df.isnull()
missing_data.head(5)
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# 3
# False    204
# Name: 3, dtype: int64
#
# ?
# False    204
# Name: ?, dtype: int64
#
# alfa-romero
# False    204
# Name: alfa-romero, dtype: int64
#
# gas
# False    204
# Name: gas, dtype: int64
#
# std
# False    204
# Name: std, dtype: int64
#
# two
# False    204
# Name: two, dtype: int64
#
# convertible
# False    204
# Name: convertible, dtype: int64
#
# rwd
# False    204
# Name: rwd, dtype: int64
#
# front
# False    204
# Name: front, dtype: int64
#
# 88.6
# False    204
# Name: 88.6, dtype: int64
#
# 168.8
# False    204
# Name: 168.8, dtype: int64
#
# 64.1
# False    204
# Name: 64.1, dtype: int64
#
# 48.8
# False    204
# Name: 48.8, dtype: int64
#
# 2548
# False    204
# Name: 2548, dtype: int64
#
# dohc
# False    204
# Name: dohc, dtype: int64
#
# four
# False    204
# Name: four, dtype: int64
#
# 130
# False    204
# Name: 130, dtype: int64
#
# mpfi
# False    204
# Name: mpfi, dtype: int64
#
# 3.47
# False    204
# Name: 3.47, dtype: int64
#
# 2.68
# ...

# %%
import pandas as pd
df=pd.read_csv('new_auto.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df['avg_norm_loss'] = df["normalized-losses"].replace("%","",inplace=True)
print("Average of normalized-losses:",df ['avg_norm_loss'])
# Out:
# Average of normalized-losses: 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 199    None
# 200    None
# 201    None
# 202    None
# 203    None
# Name: avg_norm_loss, Length: 204, dtype: object

# %%
import pandas as pd
import numpy as np
df.replace("?", np.nan, inplace = True)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            1               NaN  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               NaN         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
avg_norm_loss = df["normalized-losses"].astype("float").mean(axis=0)
print("Average of normalized-losses:", avg_norm_loss)
# Out:
# Average of normalized-losses: 122.0

# %%
df["normalized-losses"].replace(np.nan, avg_norm_loss, inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
avg_bore=df['bore'].astype('float').mean(axis=0)
print("Average of bore:", avg_bore)
# Out:
# Average of bore: 3.3290500000000014

# %%
df["bore"].replace(np.nan, avg_bore, inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
avg_stroke=df["stroke"].astype('float').mean(axis=0)
print("Average of stroke:",avg_stroke)
# Out:
# Average of stroke: 3.258299999999994

# %%
df["stroke"].replace(np.nan,avg_stroke,inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
avg_horsepower=df["horsepower"].astype("float").mean(axis=0)
avg_horsepower
# Out:
# 104.22277227722772

# %%
df["horsepower"].replace(np.nan,avg_horsepower,inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
avg_peakrpm=df['peak-rpm'].astype('float').mean(axis=0)
print("Average peak rpm:", avg_peakrpm)
# Out:
# Average peak rpm: 5125.990099009901

# %%
df['peak-rpm'].replace(np.nan,avg_peakrpm,inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df['num-of-doors'].value_counts()
# Out:
# four    114
# two      88
# Name: num-of-doors, dtype: int64

# %%
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
df["num-of-doors"].replace(np.nan, "four", inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.dropna(subset=["price"], axis=0, inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 195         -1                95        volvo       gas        std
# 196         -1                95        volvo       gas      turbo
# 197         -1                95        volvo       gas        std
# 198         -1                95        volvo    diesel      turbo
# 199         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 195         -1                95        volvo       gas        std
# 196         -1                95        volvo       gas      turbo
# 197         -1                95        volvo       gas        std
# 198         -1                95        volvo    diesel      turbo
# 199         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# avg_norm_loss         object
# dtype: object

# %%
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")

# %%
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# avg_norm_loss         object
# dtype: object

# %%
df['city-L/100km'] = 235/df["city-mpg"]

# %%
df.head(6)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
# 5          1                158         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
# ...

# %%
df["highway-mpg"]=235*df["highway-L/100km"]

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            1                122  alfa-romero       gas        std
# 2            2                164         audi       gas        std
# 3            2                164         audi       gas        std
# 4            2                122         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1                 95        volvo       gas        std
# 196         -1                 95        volvo       gas      turbo
# 197         -1                 95        volvo       gas        std
# 198         -1                 95        volvo    diesel      turbo
# 199         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df.rename(index={"highway-mpg":"highwayL/100"},inplace=True)

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            1                122  alfa-romero       gas        std
# 2            2                164         audi       gas        std
# 3            2                164         audi       gas        std
# 4            2                122         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1                 95        volvo       gas        std
# 196         -1                 95        volvo       gas      turbo
# 197         -1                 95        volvo       gas        std
# 198         -1                 95        volvo    diesel      turbo
# 199         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df['length'] = df['length']/df['length'].max()
df['width'] = df['width']/df['width'].max()

# %%
df["length"]
# Out:
# 0      0.811148
# 1      0.822681
# 2      0.848630
# 3      0.848630
# 4      0.851994
#          ...
# 195    0.907256
# 196    0.907256
# 197    0.907256
# 198    0.907256
# 199    0.907256
# Name: length, Length: 200, dtype: float64

# %%
df["height"]=df["height"]/df["height"].max()

# %%
df["height"]
# Out:
# 0      0.816054
# 1      0.876254
# 2      0.908027
# 3      0.908027
# 4      0.887960
#          ...
# 195    0.928094
# 196    0.928094
# 197    0.928094
# 198    0.928094
# 199    0.928094
# Name: height, Length: 200, dtype: float64

# %%
df["horsepower"]=df["horsepower"].astype(int, copy=True)

# %%
df["horsepower"]
# Out:
# 0      111
# 1      154
# 2      102
# 3      115
# 4      110
#       ...
# 195    114
# 196    160
# 197    134
# 198    106
# 199    114
# Name: horsepower, Length: 200, dtype: int32

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["horsepower"])

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111               Low
# 1          154            Medium
# 2          102               Low
# 3          115               Low
# 4          110               Low
# 5          110               Low
# 6          110               Low
# 7          140            Medium
# 8          101               Low
# 9          101               Low
# 10         121            Medium
# 11         121            Medium
# 12         121            Medium
# 13         182            Medium
# 14         182            Medium
# 15         182            Medium
# 16          48               Low
# 17          70               Low
# 18          70               Low
# 19          68               Low

# %%
df["horsepower-binned"].value_counts()
# Out:
# Low       152
# Medium     43
# High        5
# Name: horsepower-binned, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["horsepower-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

a = (0,1,2)

# draw historgram of attribute "horsepower" with bins = 3
plt.pyplot.hist(df["horsepower"], bins = 3)

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'avg_norm_loss', 'city-L/100km',
#        'highway-L/100km', 'horsepower-binned'],
#       dtype='object')

# %%
dummy_variable_1 = pd.get_dummies(df["fuel-type"])
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
dummy_variable_1.rename(columns={'fuel-type-diesel':'gas', 'fuel-type-diesel':'diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
dummy_variable_2 = pd.get_dummies(df["aspiration"])
dummy_variable_2.rename(columns={'aspiration-turbo':'turbo', 'aspiration-std':'std'}, inplace=True)
dummy_variable_2.head()
# Out:
#    std  turbo
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
dummy_variable_2.rename(columns={'std':'aspiration-std', 'turbo': 'aspiration-turbo'}, inplace=True)
dummy_variable_2.head()
# Out:
#    aspiration-std  aspiration-turbo
# 0               1                 0
# 1               1                 0
# 2               1                 0
# 3               1                 0
# 4               1                 0

# %%
df = pd.concat([df, dummy_variable_2], axis=1)

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            1                122  alfa-romero       gas        std
# 2            2                164         audi       gas        std
# 3            2                164         audi       gas        std
# 4            2                122         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 195         -1                 95        volvo       gas        std
# 196         -1                 95        volvo       gas      turbo
# 197         -1                 95        volvo       gas        std
# 198         -1                 95        volvo    diesel      turbo
# 199         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df.drop('aspiration', axis = 1, inplace=True)

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type num-of-doors  \
# 0            3                122  alfa-romero       gas          two
# 1            1                122  alfa-romero       gas          two
# 2            2                164         audi       gas         four
# 3            2                164         audi       gas         four
# 4            2                122         audi       gas          two
# ..         ...                ...          ...       ...          ...
# 195         -1                 95        volvo       gas         four
# 196         -1                 95        volvo       gas         four
# 197         -1                 95        volvo       gas         four
# 198         -1                 95        volvo    diesel         four
# 199         -1                 95        volvo       gas         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
df.to_csv('clean_df.csv')

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type num-of-doors  \
# 0            3                122  alfa-romero       gas          two
# 1            1                122  alfa-romero       gas          two
# 2            2                164         audi       gas         four
# 3            2                164         audi       gas         four
# 4            2                122         audi       gas          two
# ..         ...                ...          ...       ...          ...
# 195         -1                 95        volvo       gas         four
# 196         -1                 95        volvo       gas         four
# 197         -1                 95        volvo       gas         four
# 198         -1                 95        volvo    diesel         four
# 199         -1                 95        volvo       gas         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...
